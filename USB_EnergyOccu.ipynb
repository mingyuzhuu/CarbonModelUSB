# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\AdminUser'

# %%
import matplotlib
import pandas as pd
import numpy as np
import json
import math
import urllib.request
import dateutil.parser
import dateutil.rrule
import datetime
import pytz
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import collections
from textwrap import wrap

# %%
matplotlib.rcParams.update({
    'font.size':13,
    'timezone': 'Europe/London'
})

# %%
# Used across all of the plots 
dateToday = datetime.datetime.combine(datetime.date.today(),datetime.datetime.min.time())

# How many seconds between readings in trhe files that are generated. 900s = 15 mins data
resampleFrequency = 900

# %%
# These timestamps are in ISO8601 format. You can Google this for more information.
# YYYY-MM-DDTHH:MM:SSZ - always in UTC, no British Summer Time
# Be aware that you probably need to request a little bit more than you want, because
# otherwise there could be gaps at the start and end where the value didn't change...
requestFrom = '2019-12-31T23:00:00Z' # To include the end of the previous working week...
requestTo = '2020-01-01T00:00:00Z'

# %%
usbRequestBase = 'https://api.usb.urbanobservatory.ac.uk/api/v2.0a/sensors/entity'

# Fetch a list of all the entities in the Urban Sciences Building
usbResources = []

requestPage = 1
response = None

filterMetrics = ['Room Occupied']
filterUnits = []

while response is None or len(response) > 1:
  print('Fetching page %u...' % requestPage)

  response = json.loads(
      urllib.request.urlopen(
        '%s?page=%u' % (usbRequestBase, requestPage)
      ).read().decode('utf-8')
  )['items']

  requestPage = requestPage + 1

  for entity in response:
    for feed in entity['feed']:
      for timeseries in feed['timeseries']:
        if 'latest' in timeseries and 'error' in timeseries['latest']:
          # No access to some of the personal data timeseries
          continue
        for link in timeseries['links']:
          if (link['rel'] == 'archives' and \
            'latest' in timeseries):

            if feed['metric'] in filterMetrics or \
               timeseries['unit']['name'] in filterUnits:
              usbResources.append({
                  'entity': entity['name'],
                  'roomNumber': entity['meta'].get('roomNumber', 'Unknown'),
                  'roomZone': entity['meta'].get('roomZone', 'None'),
                  'bmsId': feed['brokerage'][0]['sourceId'],
                  'metric': feed['metric'],
                  'units': timeseries['unit']['name'],
                  'timeseriesIri': link['href']
              })

print('Discovered %u entities.' % len(usbResources))
# Out:
# Fetching page 1...
# Fetching page 2...
# Fetching page 3...
# Fetching page 4...
# Fetching page 5...
# Fetching page 6...
# Fetching page 7...
# Fetching page 8...
# Fetching page 9...
# Fetching page 10...
# Fetching page 11...
# Fetching page 12...
# Fetching page 13...
# Fetching page 14...
# Fetching page 15...
# Fetching page 16...
# Fetching page 17...
# Fetching page 18...
# Fetching page 19...
# Fetching page 20...
# Fetching page 21...
# Fetching page 22...
# Fetching page 23...
# Fetching page 24...
# Fetching page 25...
# Fetching page 26...
# Fetching page 27...
# Fetching page 28...
# Fetching page 29...
# Fetching page 30...
# Fetching page 31...
# Fetching page 32...
# Fetching page 33...
# Fetching page 34...
# Fetching page 35...
# Fetching page 36...
# Fetching page 37...
# Fetching page 38...
# Fetching page 39...
# Fetching page 40...
# Fetching page 41...
# Fetching page 42...
# Fetching page 43...
# Fetching page 44...
# Fetching page 45...
# Fetching page 46...
# Fetching page 47...
# Fetching page 48...
# Fetching page 49...
# Fetching page 50...
# Fetching page 51...
# Fetching page 52...
# Fetching page 53...
# Fetching page 54...
# Fetching page 55...
# Fetching page 56...
# Fetching page 57...
# Fetching page 58...
# Fetching page 59...
# Fetching page 60...
# Fetching page 61...
# Fetching page 62...
# Discovered 227 entities.

# %%
usbMetadata = pd.DataFrame.from_records(usbResources)

# Only the first 20 rows will be displayed below, but the rest will be stored to a file
usbMetadata.head(20)
# Out:
#                                               entity roomNumber roomZone  \
# 0                   Urban Sciences Building: Floor 1    Unknown     None
# 1     Urban Sciences Building: Floor 1 Accessible WC    Unknown     None
# 2   Urban Sciences Building: Floor 1 Ambient Kitchen    Unknown     None
# 3     Urban Sciences Building: Floor 1 Collaboration    Unknown     None
# 4     Urban Sciences Building: Floor 1 Collaboration    Unknown     None
# 5        Urban Sciences Building: Floor 1 DIG Zone 1    Unknown        1
# 6       Urban Sciences Building: Floor 1 DIG Zone 10    Unknown       10
# 7       Urban Sciences Building: Floor 1 DIG Zone 11    Unknown       11
# 8       Urban Sciences Building: Floor 1 DIG Zone 12    Unknown       12
# 9       Urban Sciences Building: Floor 1 DIG Zone 13    Unknown       13
# 10      Urban Sciences Building: Floor 1 DIG Zone 14    Unknown       14
# 11      Urban Sciences Building: Floor 1 DIG Zone 15    Unknown       15
# 12      Urban Sciences Building: Floor 1 DIG Zone 16    Unknown       16
# 13      Urban Sciences Building: Floor 1 DIG Zone 17    Unknown       17
# 14       Urban Sciences Building: Floor 1 DIG Zone 3    Unknown        3
# 15       Urban Sciences Building: Floor 1 DIG Zone 4    Unknown        4
# 16       Urban Sciences Building: Floor 1 DIG Zone 5    Unknown        5
# 17       Urban Sciences Building: Floor 1 DIG Zone 6    Unknown        6
# 18       Urban Sciences Building: Floor 1 DIG Zone 7    Unknown        7
# 19       Urban Sciences Building: Floor 1 DIG Zone 9    Unknown        9
#
#                            bmsId         metric    units  \
# 0             125_WC's_1.032_Occ  Room Occupied  unknown
# 1     111_AccessibleWC_1.013_Occ  Room Occupied  unknown
# 2   117_AmbientKitchen_1.018_Occ  Room Occupied  unknown
# 3    105_Collaboration_1.005_Occ  Room Occupied  unknown
# 4    109_Collaboration_1.010_Occ  Room Occupied  unknown
# 5           118_DIG_1.024_Z1_Occ  Room Occupied  unknown
# 6          118_DIG_1.024_Z10_Occ  Room Occupied  unknown
# 7          118_DIG_1.024_Z11_Occ  Room Occupied  unknown
# 8          118_DIG_1.024_Z12_Occ  Room Occupied  unknown
# 9          118_DIG_1.024_Z13_Occ  Room Occupied  unknown
# 10         118_DIG_1.024_Z14_Occ  Room Occupied  unknown
# 11         118_DIG_1.024_Z15_Occ  Room Occupied  unknown
# 12         118_DIG_1.024_Z16_Occ  Room Occupied  unknown
# 13         118_DIG_1.024_Z17_Occ  Room Occupied  unknown
# 14          118_DIG_1.024_Z3_Occ  Room Occupied  unknown
# 15          118_DIG_1.024_Z4_Occ  Room Occupied  unknown
# 16          118_DIG_1.024_Z5_Occ  Room Occupied  unknown
# 17          118_DIG_1.024_Z6_Occ  Room Occupied  unknown
# 18          118_DIG_1.024_Z7_Occ  Room Occupied  unknown
# 19          118_DIG_1.024_Z9_Occ  Room Occupied  unknown
#
#                                         timeseriesIri
# 0   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 1   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 2   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 3   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 4   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 5   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 6   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 7   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 8   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 9   https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 10  https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 11  https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 12  https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 13  https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 14  https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 15  https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 16  https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 17  https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 18  https://api.usb.urbanobservatory.ac.uk/api/v2/...
# 19  https://api.usb.urbanobservatory.ac.uk/api/v2/...

# %%
usbMetadata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 227 entries, 0 to 226
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   entity         227 non-null    object
#  1   roomNumber     227 non-null    object
#  2   roomZone       227 non-null    object
#  3   bmsId          227 non-null    object
#  4   metric         227 non-null    object
#  5   units          227 non-null    object
#  6   timeseriesIri  227 non-null    object
# dtypes: object(7)
# memory usage: 12.5+ KB

# %%
def downloadTimeseries(columnName, sourceIri, startTime, endTime, daysPerRequest = 15):
  print('  [', end='')

  timeStart = datetime.datetime.strptime(startTime, "%Y-%m-%dT%H:%M:%SZ")
  timeEnd = datetime.datetime.strptime(endTime, "%Y-%m-%dT%H:%M:%SZ")

  tsRecords = []

  for windowStart in dateutil.rrule.rrule(
      dateutil.rrule.DAILY,
      interval=daysPerRequest,
      dtstart=timeStart,
      until=timeEnd
    ):

    windowEnd = windowStart + pd.Timedelta(days=daysPerRequest) - pd.Timedelta(seconds=1)
    if windowEnd > timeEnd:
      windowEnd = timeEnd

    windowResponse = json.loads(
        urllib.request.urlopen(
          '%s?startTime=%s&endTime=%s' % (sourceIri, windowStart.isoformat().replace('+00:00', 'Z'), windowEnd.isoformat().replace('+00:00', 'Z'))
        ).read().decode('utf-8')
    )['historic']['values']

    tsRecords.extend(windowResponse)
    print('.', end='')

  print(']')

  if len(tsRecords) < 1:
    return None
  
  dfTs = pd.DataFrame.from_records(tsRecords, exclude=['duration'])

  # Times in this API are in ISO8601
  dfTs['time'] = dfTs['time'].apply(lambda t: datetime.datetime.strptime(t, "%Y-%m-%dT%H:%M:%S.%fZ"))
  
  dfTs = dfTs.rename(columns={'value': columnName})
  dfTs.set_index('time', inplace=True, drop=True)

  return dfTs

# %%
# These timestamps are in ISO8601 format. You can Google this for more information.
# YYYY-MM-DDTHH:MM:SSZ - always in UTC, no British Summer Time
# Be aware that you probably need to request a little bit more than you want, because
# otherwise there could be gaps at the start and end where the value didn't change...
#requestFrom = '2019-03-01T00:00:00Z' # To include the end of the previous working week...
#requestTo = '2020-03-02T00:00:00Z'

# %%
dfRooms = None

print('Requesting USB room data...')

for idx, row in usbMetadata.iterrows():
  ts = row.to_dict()
  print('  %s' % ts['entity'])

  pdTs = downloadTimeseries(
    ts['bmsId'],
    ts['timeseriesIri'],
    requestFrom,
    requestTo
  )

  if pdTs is None:
    continue

  # The way the data is stored in the USB, is that unless the value changes, nothing
  # is stored. This does a forward fill, repeating the previous value until a new one
  # is identified.
  pdTs = pdTs.resample('%us' % resampleFrequency).ffill()

  if dfRooms is None:
    dfRooms = pdTs
  else:
    dfRooms = dfRooms.join(pdTs, how='outer')

dfRooms.head(20)
# Out:
# Requesting USB room data...
#   Urban Sciences Building: Floor 1
#   [.]
#   Urban Sciences Building: Floor 1 Accessible WC
#   [.]
#   Urban Sciences Building: Floor 1 Ambient Kitchen
#   [.]
#   Urban Sciences Building: Floor 1 Collaboration
#   [.]
#   Urban Sciences Building: Floor 1 Collaboration
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 1
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 10
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 11
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 12
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 13
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 14
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 15
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 16
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 17
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 3
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 4
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 5
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 6
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 7
#   [.]
#   Urban Sciences Building: Floor 1 DIG Zone 9
#   [.]
#   Urban Sciences Building: Floor 1 Design Research Workshop
#   [.]
#   Urban Sciences Building: Floor 1 Electronic Workshop
#   [.]
#   Urban Sciences Building: Floor 1 Female WC
#   [.]
#   Urban Sciences Building: Floor 1 MSc Zone 2
#   [.]
#   Urban Sciences Building: Floor 1 MSc Zone 3
#   [.]
#   Urban Sciences Building: Floor 1 Maker Space Zone 1
#   [.]
#   Urban Sciences Building: Floor 1 Maker Space Zone 2
#   [.]
#   Urban Sciences Building: Floor 1 Male WC
#   [.]
#   Urban Sciences Building: Floor 1 Meeting
#   [.]
#   Urban Sciences Building: Floor 1 Meeting
#   [.]
#   Urban Sciences Building: Floor 1 Meeting Room
#   [.]
#   Urban Sciences Building: Floor 1 TVStudio Research
#   [.]
#   Urban Sciences Building: Floor 1 WC Lobby
#   [.]
#   Urban Sciences Building: Floor 1 eSocial Learning
#   [.]
#   Urban Sciences Building: Floor 2 Admin Zone 1
#   [.]
#   Urban Sciences Building: Floor 2 Admin Zone 3
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.004
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.005
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.008
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.010
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.011
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.012
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.014
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.015
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.017
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.020
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.021
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.022 Zone 2
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.026
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.027
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.037 Zone 1
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.037 Zone 2
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.038 Zone 1
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.038 Zone 2
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.048 Zone 1
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.048 Zone 2
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.048 Zone 4
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.048 Zone 5
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.058 Zone 1
#   [.]
#   Urban Sciences Building: Floor 2: Room 2.060
#   [.]
#   Urban Sciences Building: Floor 3 Circulation
#   [.]
#   Urban Sciences Building: Floor 3 Meeting Area
#   [.]
#   Urban Sciences Building: Floor 3 Meeting Area
#   [.]
#   Urban Sciences Building: Floor 3 Meeting Room
#   [.]
#   Urban Sciences Building: Floor 3 Scalable And Cloud
#   [.]
#   Urban Sciences Building: Floor 3 Scalable And Cloud
#   [.]
#   Urban Sciences Building: Floor 3 Scalable And Cloud
#   [.]
#   Urban Sciences Building: Floor 3 Scalable And Cloud
#   [.]
#   Urban Sciences Building: Floor 3 Scalable And Cloud
#   [.]
#   Urban Sciences Building: Floor 3 Scalable And Cloud Zone 1
#   [.]
#   Urban Sciences Building: Floor 3 Scalable And Cloud Zone 2
#   [.]
#   Urban Sciences Building: Floor 3 Scalable And Cloud Zone 3
#   [.]
#   Urban Sciences Building: Floor 3 TS2a Flat Floor Teaching Zone 1
#   [.]
#   Urban Sciences Building: Floor 3 TS2a Flat Floor Teaching Zone 2
#   [.]
#   Urban Sciences Building: Floor 3 TS2a Flat Floor Teaching Zone 3
#   [.]
#   Urban Sciences Building: Floor 3 TS2a Flat Floor Teaching Zone 4
#   [.]
#   Urban Sciences Building: Floor 3 Tea Point
#   [.]
#   Urban Sciences Building: Floor 3 WC Lobby
#   [.]
#   Urban Sciences Building: Floor 3 Workspace Zone 1
#   [.]
#   Urban Sciences Building: Floor 3 Workspace Zone 2
#   [.]
#   Urban Sciences Building: Floor 3 Workspace Zone 3
#   [.]
#   Urban Sciences Building: Floor 3 Workspace Zone 4
#   [.]
#   Urban Sciences Building: Floor 3 Workspace Zone 5
#   [.]
#   Urban Sciences Building: Floor 4 Access WC
#   [.]
#   Urban Sciences Building: Floor 4 Circulation
#   [.]
#   Urban Sciences Building: Floor 4 Lobby
#   [.]
#   Urban Sciences Building: Floor 4 Meeting
#   [.]
#   Urban Sciences Building: Floor 4 Meeting
#   [.]
#   Urban Sciences Building: Floor 4 Meeting Room
#   [.]
#   Urban Sciences Building: Floor 4 Scalable
#   [.]
#   Urban Sciences Building: Floor 4 Scalable
#   [.]
#   Urban Sciences Building: Floor 4 Scalable
#   [.]
#   Urban Sciences Building: Floor 4 Tea Point
#   [.]
#   Urban Sciences Building: Floor 4 Typical
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.022 Zone 1
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.022 Zone 2
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.022 Zone 3
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.022 Zone 4
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.037 Zone 2
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.037 Zone 3
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.037 Zone 4
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.037 Zone 5
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.052 Zone 1
#   [.]
#   Urban Sciences Building: Floor 4: Room 4.052 Zone 3
#   [.]
#   Urban Sciences Building: Floor 5 Access WC
#   [.]
#   Urban Sciences Building: Floor 5 ICOS
#   [.]
#   Urban Sciences Building: Floor 5 ICOS
#   [.]
#   Urban Sciences Building: Floor 5 ICOS
#   [.]
#   Urban Sciences Building: Floor 5 ICOS
#   [.]
#   Urban Sciences Building: Floor 5 ICOSEquip
#   [.]
#   Urban Sciences Building: Floor 5 ICOSProj
#   [.]
#   Urban Sciences Building: Floor 5 Lobby
#   [.]
#   Urban Sciences Building: Floor 5 Meeting
#   [.]
#   Urban Sciences Building: Floor 5 Tea Point
#   [.]
#   Urban Sciences Building: Floor 5 WCs
#   [.]
#   Urban Sciences Building: Floor 5: Room 5.008 Zone 1
#   [.]
#   Urban Sciences Building: Floor 5: Room 5.008 Zone 2
#   [.]
#   Urban Sciences Building: Floor 5: Room 5.008 Zone 3
#   [.]
#   Urban Sciences Building: Floor 5: Room 5.008 Zone 4
#   [.]
#   Urban Sciences Building: Floor 5: Room 5.008 Zone 5
#   [.]
#   Urban Sciences Building: Floor 5: Room 5.008 Zone 6
#   [.]
#   Urban Sciences Building: Floor 5: Room 5.024 Zone 1
#   [.]
#   Urban Sciences Building: Floor 5: Room 5.024 Zone 2
#   [.]
#   Urban Sciences Building: Floor 6 6Person
#   [.]
#   Urban Sciences Building: Floor 6 Access WC
#   [.]
#   Urban Sciences Building: Floor 6 Acoustic
#   [.]
#   Urban Sciences Building: Floor 6 Amber
#   [.]
#   Urban Sciences Building: Floor 6 Amber
#   [.]
#   Urban Sciences Building: Floor 6 Amber
#   [.]
#   Urban Sciences Building: Floor 6 Amber
#   [.]
#   Urban Sciences Building: Floor 6 Amber
#   [.]
#   Urban Sciences Building: Floor 6 Amber
#   [.]
#   Urban Sciences Building: Floor 6 Amber
#   [.]
#   Urban Sciences Building: Floor 6 Amber
#   [.]
#   Urban Sciences Building: Floor 6 Colab
#   [.]
#   Urban Sciences Building: Floor 6 Cyber
#   [.]
#   Urban Sciences Building: Floor 6 Lobby
#   [.]
#   Urban Sciences Building: Floor 6 Meeting
#   [.]
#   Urban Sciences Building: Floor 6 SR
#   [.]
#   Urban Sciences Building: Floor 6 SR
#   [.]
#   Urban Sciences Building: Floor 6 SR
#   [.]
#   Urban Sciences Building: Floor 6 SR
#   [.]
#   Urban Sciences Building: Floor 6 SR
#   [.]
#   Urban Sciences Building: Floor 6 SR
#   [.]
#   Urban Sciences Building: Floor 6 Tea Point
#   [.]
#   Urban Sciences Building: Floor 6 WCs
#   [.]
#   Urban Sciences Building: Floor 6: Room 6.007 Zone 1
#   [.]
#   Urban Sciences Building: Floor 6: Room 6.007 Zone 2
#   [.]
#   Urban Sciences Building: Floor 6: Room 6.031 Zone 1
#   [.]
#   Urban Sciences Building: Floor 6: Room 6.031 Zone 2
#   [.]
#   Urban Sciences Building: Floor G Back Projection
#   [.]
#   Urban Sciences Building: Floor G Cafe Store
#   [.]
#   Urban Sciences Building: Floor G Computer Workshop
#   [.]
#   Urban Sciences Building: Floor G Cyber Physical
#   [.]
#   Urban Sciences Building: Floor G Decision Theatre
#   [.]
#   Urban Sciences Building: Floor G EPTCell
#   [.]
#   Urban Sciences Building: Floor G EPTCell
#   [.]
#   Urban Sciences Building: Floor G EPTControl
#   [.]
#   Urban Sciences Building: Floor G Female Showers
#   [.]
#   Urban Sciences Building: Floor G SUDS Laboratory
#   [.]
#   Urban Sciences Building: Floor G Servery
#   [.]
#   Urban Sciences Building: Floor G Shared Labs
#   [.]
#   Urban Sciences Building: Floor G Shared Work
#   [.]
#   Urban Sciences Building: Floor G Smart Grid
#   [.]
#   Urban Sciences Building: Floor G: Room G.009 Zone 1
#   [.]
#   Urban Sciences Building: Floor G: Room G.071 Zone 1
#   [.]
#                      118_DIG_1.024_Z3_Occ  135_MeetingRoom_1.043_Occ  \
# time
# 2019-12-31 23:15:00                   NaN                        NaN
# 2019-12-31 23:30:00                   1.0                        1.0
#
#                      Zone1_BMSControl.RmHVAC.208_StudentRefresh_2.008_Occ
# time
# 2019-12-31 23:15:00                                                NaN
# 2019-12-31 23:30:00                                                NaN

# %%
# These timestamps are in ISO8601 format. You can Google this for more information.
# YYYY-MM-DDTHH:MM:SSZ - always in UTC, no British Summer Time
# Be aware that you probably need to request a little bit more than you want, because
# otherwise there could be gaps at the start and end where the value didn't change...
#requestFrom = '2019-01-07T00:00:00Z' # To include the end of the previous working week...
#requestTo = '2020-01-21T00:00:00Z'

# %%
# Write to an Excel file...

outputWriter = pd.ExcelWriter(
  'urban-sciences-building-data.xlsx',
  engine='xlsxwriter',
  datetime_format='mmm d yyyy hh:mm:ss',
  date_format='mmmm dd yyyy'
)

# Add sheets
usbMetadata.to_excel(outputWriter, sheet_name='Room metadata')
dfRooms.to_excel(outputWriter, sheet_name='Room occupancy')
#dfPower.to_excel(outputWriter, sheet_name='Power consumption')

outputWriter.save()
